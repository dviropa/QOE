# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score
import faiss  # pip install faiss-cpu
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# %%
RED = "\033[31m"
GREEN = "\033[32m"
YELLOW = "\033[33m"
BLUE = "\033[34m"
RESET = "\033[0m"

# %%
files = [
    "output/subset_window_1754898203.csv","output/window_1_1756028067.csv",
    "output/window_3_1756030271.csv",
    "output/window_5_1756032959.csv","output/window_10_1754904064.csv","output/window_15_1756035248.csv"
]
# merged_df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# merged_df.to_csv("output/merged_selected.csv", index=False)

# %%
FEATURE_COLUMNS = [
            'src2dst_avg_pkt_size', 'src2dst_avg_pkt_size_mean', 'src2dst_avg_pkt_size_median',
            'src2dst_avg_pkt_size_std', 'src2dst_avg_pkt_size_min', 'src2dst_avg_pkt_size_max',
            'src2dst_pps', 'src2dst_pps_mean', 'src2dst_pps_median',
            'src2dst_pps_std', 'src2dst_pps_min', 'src2dst_pps_max',
            'dst2src_avg_pkt_size', 'dst2src_avg_pkt_size_mean', 'dst2src_avg_pkt_size_median',
            'dst2src_avg_pkt_size_std', 'dst2src_avg_pkt_size_min', 'dst2src_avg_pkt_size_max',
            'dst2src_pps', 'dst2src_pps_mean', 'dst2src_pps_median',
            'dst2src_pps_std', 'dst2src_pps_min', 'dst2src_pps_max',
            'pkt_dir_ratio', 'pkt_dir_ratio_mean', 'pkt_dir_ratio_median',
            'pkt_dir_ratio_std', 'pkt_dir_ratio_min', 'pkt_dir_ratio_max']

# %%
def vectordb(X_train, X_test, y_train, y_test,k):
    try:



        scaler = StandardScaler()
        X_train_sc = scaler.fit_transform(X_train).astype('float32')
        X_test_sc = scaler.transform(X_test).astype('float32')

        d = X_train_sc.shape[1]
        index = faiss.IndexFlatL2(d)  
        index.add(X_train_sc)  # מוסיפים את הווקטורים

        # 5) חיפוש k שכנים ו־Majority Vote
        k  = min(k, len(X_train_sc))
        D, I = index.search(X_test_sc, k)  # D=מרחקים, I=אינדקסים של השכנים (ב-X_train_sc)

        def majority_vote(neighbor_indices):
            labels = y_train[neighbor_indices]
            vals, counts = np.unique(labels, return_counts=True)
            return vals[np.argmax(counts)]

        y_pred = np.array([majority_vote(I[i]) for i in range(len(X_test_sc))])

        # 6) הערכה
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='macro')
        # print(f"FAISS-kNN → Accuracy: {acc:.3f} | Macro-F1: {f1:.3f}")
        return acc,f1
    except Exception as e:
        print(f"   שגיאה: {e}")

# %%
def vectordb5filde(df,k):
    from rank import rank_qoe_3_classes, rank_str_to_int_mapping_3_classes
    df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
    df['y_qoe_by_ping'] = df['ping'].apply(
        lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)]
    )

    X = df[FEATURE_COLUMNS].values.astype('float32')
    y = df['y_qoe_by_ping'].values.astype('int64')

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    accs, f1s = [], []
    for fold, (train_index, test_index) in enumerate(skf.split(X, y), start=1):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]


        acc, f1 = vectordb(X_train, X_test, y_train, y_test,k)
        accs.append(acc); f1s.append(f1)


    return accs ,f1s

# %%
def _5filde(df,clf):
    from rank import rank_qoe_3_classes, rank_str_to_int_mapping_3_classes
    df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
    df['y_qoe_by_ping'] = df['ping'].apply(
        lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)]
    )

    X = df[FEATURE_COLUMNS].values.astype('float32')
    y = df['y_qoe_by_ping'].values.astype('int64')

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    accs, f1s = [], []
    for fold, (train_index, test_index) in enumerate(skf.split(X, y), start=1):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)

        acc = accuracy_score(y_test, y_pred)
        f1  = f1_score(y_test, y_pred, average='macro')

        
        accs.append(acc); f1s.append(f1)


    return accs ,f1s

# %%
for file in files:
    try:
        df = pd.read_csv(file)
        print(f"\n{BLUE}=== File: {file} ==={RESET}")

        t_df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
        # max_accs=0 
        # max_f1s=0
        max_k=3
        # for k in range(1,2):
        accs ,f1s=vectordb5filde(t_df,max_k)
            # if max_accs <np.mean(accs) :
            #     max_accs=np.mean(accs) 
            #     max_f1s=np.mean(f1s)
            #     max_k=k

        print(f"AVG over 5 folds →{GREEN} Accuracy:{RESET} {np.mean(accs):.3f}| "
                    f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f}            k={max_k}")
        # print(f"AVG over 5 folds →{GREEN} Accuracy:{RESET} {np.mean(max_accs):.3f} ± {np.std(accs):.3f} | "
        #         f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f} ± {np.std(max_f1s):.3f} /n  k={max_k}" )
    except Exception as e:
        print(RED + f"MODEL FAILED: {name}" + RESET)
        print(traceback.format_exc())
# Out:
# === File: output/subset_window_1754898203.csv ===
# AVG over 5 folds → Accuracy: 0.980| Macro-F1: 0.980            k=3
#
# === File: output/window_1_1756028067.csv ===
# MODEL FAILED: XGBoost
# Traceback (most recent call last):
#   File "/tmp/ipykernel_2541/1045817702.py", line 11, in <module>
#     accs ,f1s=vectordb5filde(t_df,max_k)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_2541/2765076414.py", line 14, in vectordb5filde
#     for fold, (train_index, test_index) in enumerate(skf.split(X, y), start=1):
#                                                      ^^^^^^^^^^^^^^^
#   File "/home/codespace/.local/lib/python3.12/site-packages/sklearn/model_selection/_split.py", line 887, in split
#     y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1128, in check_array
#     raise ValueError(
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
#
# === File: output/window_3_1756030271.csv ===
# AVG over 5 folds → Accuracy: 0.747| Macro-F1: 0.745            k=3
#
# === File: output/window_5_1756032959.csv ===
# AVG over 5 folds → Accuracy: 0.808| Macro-F1: 0.807            k=3
#
# === File: output/window_10_1754904064.csv ===
# AVG over 5 folds → Accuracy: 0.897| Macro-F1: 0.898            k=3
#
# === File: output/window_15_1756035248.csv ===
# AVG over 5 folds → Accuracy: 0.937| Macro-F1: 0.938            k=3

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from rank import rank_qoe_3_classes, rank_str_to_int_mapping_3_classes






from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier




from sklearn.metrics import confusion_matrix
import seaborn as sns, matplotlib.pyplot as plt

# %%
def make_models(n_classes: int):
    models = [
        ('RF', RandomForestClassifier(random_state=42)),
        ('DT', DecisionTreeClassifier(random_state=42)),
        # LR ו-SVM נהנים מ־StandardScaler → נעטוף אותם ב־Pipeline
        ('LR', make_pipeline(StandardScaler(), LogisticRegression(random_state=42, max_iter=1000, multi_class='auto'))),
        ('SVM', make_pipeline(StandardScaler(), SVC(random_state=42)))  # אם צריך הסתברויות: SVC(probability=True)
    ]
    if n_classes == 2:
        xgb = XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=42)
    else:
        xgb = XGBClassifier(objective='multi:softprob', num_class=n_classes, eval_metric='mlogloss', random_state=42)
    models.append(('XGBoost', xgb))
    return models

# %%
# for file in files:
#     df = pd.read_csv(file) 
#     df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
#     df['y'] = df['ping'].apply(lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)])

from sklearn.preprocessing import LabelEncoder

#     X = df[FEATURE_COLUMNS].values.astype('float32')

#     le = LabelEncoder()
#     y = le.fit_transform(df['y'].values)   # יהפוך {1,2,3} ל-{0,1,2}

#     X_train, X_test, y_train, y_test = train_test_split(
#         X, y, test_size=0.2, stratify=y, random_state=42
#     )



#     models = make_models(n_classes=len(np.unique(y_train)))
#     for name, clf in models:
#         acc, f1=_5filde(df,clf)
#         print(f" →{GREEN} Accuracy:{RESET} {np.mean(acc):.3f}| "
#                 f"{RED}Macro-F1:{RESET} {np.mean(f1):.3f}")

#     k=5
#     accs ,f1s=vectordb5filde(df,k)
#     print(f"{name} AVG over 5 folds →{GREEN} Accuracy:{RESET} {np.mean(accs):.3f}| "
#                 f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f}            k={k}")
    



for file in files:
    try:
        print(f"\n{BLUE}=== File: {file} ==={RESET}")
        df = pd.read_csv(file)
        df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
        df['y'] = df['ping'].apply(lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)])

        k = 5
        acc, f1 = vectordb5filde(df, k)
        print(f"{YELLOW}FAISS (k={k}){RESET} → {GREEN}Accuracy:{RESET} {np.mean(acc):.3f} ± {np.std(acc):.3f} | "
                f"{RED}Macro-F1:{RESET} {np.mean(f1):.3f} ± {np.std(f1):.3f}")
        
        models = make_models(n_classes=3)  # שלוש מחלקות
        for name, clf in models:
            accs, f1s = _5filde(df, clf)  # מחזיר 5 ערכים (קיפולים)
            print(f"{name:>10} → {GREEN}Accuracy:{RESET} {np.mean(accs):.3f} ± {np.std(accs):.3f} | "
                f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f} ± {np.std(f1s):.3f}")

            # FAISS — 5 קיפולים עם k=5 (אפשר לשנות)

    except:
        print("eror")
# Out:
# === File: output/subset_window_1754898203.csv ===
# FAISS (k=5) → Accuracy: 0.976 ± 0.004 | Macro-F1: 0.975 ± 0.004
#         RF → Accuracy: 0.994 ± 0.003 | Macro-F1: 0.994 ± 0.003
#         DT → Accuracy: 0.969 ± 0.006 | Macro-F1: 0.969 ± 0.006
#         LR → Accuracy: 0.911 ± 0.015 | Macro-F1: 0.908 ± 0.014
#        SVM → Accuracy: 0.971 ± 0.007 | Macro-F1: 0.970 ± 0.007
# eror
#
# === File: output/window_1_1756028067.csv ===
# eror
#
# === File: output/window_3_1756030271.csv ===
# FAISS (k=5) → Accuracy: 0.761 ± 0.007 | Macro-F1: 0.758 ± 0.006
#         RF → Accuracy: 0.803 ± 0.005 | Macro-F1: 0.798 ± 0.006
#         DT → Accuracy: 0.720 ± 0.005 | Macro-F1: 0.720 ± 0.005
# eror
#
# === File: output/window_5_1756032959.csv ===
# FAISS (k=5) → Accuracy: 0.812 ± 0.002 | Macro-F1: 0.811 ± 0.002
# eror
#
# === File: output/window_10_1754904064.csv ===
# eror
#
# === File: output/window_15_1756035248.csv ===
# FAISS (k=5) → Accuracy: 0.929 ± 0.003 | Macro-F1: 0.930 ± 0.003
#         RF → Accuracy: 0.977 ± 0.002 | Macro-F1: 0.977 ± 0.002
# eror

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# === 1) הכנת הדאטה (התאם לשדות שלך) ===
from rank import rank_qoe_3_classes, rank_str_to_int_mapping_3_classes

FEATURE_COLUMNS = [
    'src2dst_avg_pkt_size', 'src2dst_avg_pkt_size_mean', 'src2dst_avg_pkt_size_median',
    'src2dst_avg_pkt_size_std', 'src2dst_avg_pkt_size_min', 'src2dst_avg_pkt_size_max',
    'src2dst_pps', 'src2dst_pps_mean', 'src2dst_pps_median',
    'src2dst_pps_std', 'src2dst_pps_min', 'src2dst_pps_max',
    'dst2src_avg_pkt_size', 'dst2src_avg_pkt_size_mean', 'dst2src_avg_pkt_size_median',
    'dst2src_avg_pkt_size_std', 'dst2src_avg_pkt_size_min', 'dst2src_avg_pkt_size_max',
    'dst2src_pps', 'dst2src_pps_mean', 'dst2src_pps_median',
    'dst2src_pps_std', 'dst2src_pps_min', 'dst2src_pps_max',
    'pkt_dir_ratio', 'pkt_dir_ratio_mean', 'pkt_dir_ratio_median',
    'pkt_dir_ratio_std', 'pkt_dir_ratio_min', 'pkt_dir_ratio_max'
]
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

def make_models(n_classes: int):
    models = [
        ('RF', RandomForestClassifier(random_state=42)),
        ('DT', DecisionTreeClassifier(random_state=42)),
        # LR ו-SVM נהנים מ־StandardScaler → נעטוף אותם ב־Pipeline
        ('LR', make_pipeline(StandardScaler(), LogisticRegression(random_state=42, max_iter=1000, multi_class='auto'))),
        ('SVM', make_pipeline(StandardScaler(), SVC(random_state=42)))  # אם צריך הסתברויות: SVC(probability=True)
    ]
    if n_classes == 2:
        xgb = XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=42)
    else:
        xgb = XGBClassifier(objective='multi:softprob', num_class=n_classes, eval_metric='mlogloss', random_state=42)
    models.append(('XGBoost', xgb))
    return models



for file in files:
    try:
        print(f"\n{BLUE}=== File: {file} ==={RESET}")
        df = pd.read_csv(file)
        df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
        df['y'] = df['ping'].apply(lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)])

        k = 5
        acc, f1 = vectordb5filde(df, k)
        print(f"{YELLOW}FAISS (k={k}){RESET} → {GREEN}Accuracy:{RESET} {np.mean(acc):.3f} ± {np.std(acc):.3f} | "
                f"{RED}Macro-F1:{RESET} {np.mean(f1):.3f} ± {np.std(f1):.3f}")
        
        from sklearn.preprocessing import LabelEncoder

        # ... אחרי שיצרת df['y'] ...
        X = df[FEATURE_COLUMNS].values.astype('float32')

        le = LabelEncoder()
        y = le.fit_transform(df['y'].values)   # יהפוך {1,2,3} ל-{0,1,2}

        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.2, stratify=y, random_state=42
        )
        # === 2) המודלים (כפי שהגדרת) ===


        models = make_models(n_classes=len(np.unique(y_train)))
        for name, clf in models:
            accs, f1s = _5filde(df, clf)  # מחזיר 5 ערכים (קיפולים)
            print(f"{name:>10} → {GREEN}Accuracy:{RESET} {np.mean(accs):.3f} ± {np.std(accs):.3f} | "
                f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f} ± {np.std(f1s):.3f}")

            # FAISS — 5 קיפולים עם k=5 (אפשר לשנות)

    except:
        print("eror")

# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import traceback
import warnings

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

import faiss  # pip install faiss-cpu

# ===== עיצוב פלט (לא חובה) =====
RED = "\033[31m"; GREEN = "\033[32m"; YELLOW = "\033[33m"; BLUE = "\033[34m"; RESET = "\033[0m"

# ===== פיצ'רים וקבצים =====
FEATURE_COLUMNS = [
    'src2dst_avg_pkt_size','src2dst_avg_pkt_size_mean','src2dst_avg_pkt_size_median',
    'src2dst_avg_pkt_size_std','src2dst_avg_pkt_size_min','src2dst_avg_pkt_size_max',
    'src2dst_pps','src2dst_pps_mean','src2dst_pps_median','src2dst_pps_std','src2dst_pps_min','src2dst_pps_max',
    'dst2src_avg_pkt_size','dst2src_avg_pkt_size_mean','dst2src_avg_pkt_size_median',
    'dst2src_avg_pkt_size_std','dst2src_avg_pkt_size_min','dst2src_avg_pkt_size_max',
    'dst2src_pps','dst2src_pps_mean','dst2src_pps_median','dst2src_pps_std','dst2src_pps_min','dst2src_pps_max',
    'pkt_dir_ratio','pkt_dir_ratio_mean','pkt_dir_ratio_median','pkt_dir_ratio_std','pkt_dir_ratio_min','pkt_dir_ratio_max'
]

files = [
    "output/subset_window_1754898203.csv",
    "output/window_1_1756028067.csv",
    "output/window_3_1756030271.csv",
    "output/window_5_1756032959.csv",
    "output/window_10_1754904064.csv",
    "output/window_15_1756035248.csv"
]

# ===== פונקציות עזר =====
def show_exc(where=""):
    print(RED + f"\nERROR {where}:" + RESET)
    print(traceback.format_exc())

def ensure_columns(df, needed):
    return [c for c in needed if c not in df.columns]

def class_counts(y):
    vals, cnts = np.unique(y, return_counts=True)
    return dict(zip(vals.tolist(), cnts.tolist()))

def safe_n_splits(y, max_splits=5):
    y = np.asarray(y).ravel()
    _, counts = np.unique(y, return_counts=True)
    return int(max(2, min(max_splits, counts.min())))  # 2..5, לא מעבר למינ' לדגימות במחלקה

# ===== מודלי sklearn =====
def make_models(n_classes: int):
    models = [
        ('RF',  RandomForestClassifier(random_state=42)),
        ('DT',  DecisionTreeClassifier(random_state=42)),
        ('LR',  make_pipeline(StandardScaler(), LogisticRegression(
                random_state=42, max_iter=2000, solver='lbfgs', multi_class='multinomial'))),
        ('SVM', make_pipeline(StandardScaler(), SVC(random_state=42)))
    ]
    # XGBoost מולטי-קלאס
    xgb = XGBClassifier(
        objective=('multi:softprob' if n_classes > 2 else 'binary:logistic'),
        num_class=(n_classes if n_classes > 2 else None),
        eval_metric=('mlogloss' if n_classes > 2 else 'logloss'),
        random_state=42, n_estimators=300, max_depth=6,
        learning_rate=0.1, subsample=0.8, colsample_bytree=0.8,
        tree_method='hist'
    )
    models.append(('XGBoost', xgb))
    return models

# ===== FAISS-kNN כפי שאתה אוהב =====
def vectordb(X_train, X_test, y_train, y_test, k):
    # כאן מניחים שאין NaN – לכן נקרא לאחר אימפיוט
    scaler = StandardScaler()
    Xtr = scaler.fit_transform(X_train).astype('float32')
    Xte = scaler.transform(X_test).astype('float32')

    d = Xtr.shape[1]
    index = faiss.IndexFlatL2(d)
    index.add(Xtr)
    k = min(k, len(Xtr))
    _, I = index.search(Xte, k)

    preds = []
    for nn in I:
        labels = y_train[nn]
        vals, counts = np.unique(labels, return_counts=True)
        preds.append(vals[np.argmax(counts)])
    y_pred = np.array(preds)
    return accuracy_score(y_test, y_pred), f1_score(y_test, y_pred, average='macro')

# ===== ריצה ב-CV עבור מודלים של sklearn (כולל טיפול מיוחד ל-XGB בלייבלים) =====
def run_cv(df, clf, y_col, n_splits):
    X = df[FEATURE_COLUMNS].values.astype('float32')
    y = df[y_col].values.astype('int64')
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    accs, f1s = [], []
    for tr, te in skf.split(X, y):
        # אימפיוט רק על ה-train כדי לא לדלוף מידע
        imputer = SimpleImputer(strategy='median')
        X_tr = imputer.fit_transform(X[tr])
        X_te = imputer.transform(X[te])

        if isinstance(clf, XGBClassifier):
            # XGBoost דורש 0..C-1
            le = LabelEncoder()
            y_tr = le.fit_transform(y[tr])
            y_te = le.transform(y[te])
            clf.fit(X_tr, y_tr)
            y_pred = clf.predict(X_te)
            accs.append(accuracy_score(y_te, y_pred))
            f1s.append(f1_score(y_te, y_pred, average='macro'))
        else:
            clf.fit(X_tr, y[tr])
            y_pred = clf.predict(X_te)
            accs.append(accuracy_score(y[te], y_pred))
            f1s.append(f1_score(y[te], y_pred, average='macro'))
    return np.array(accs), np.array(f1s)

# ===== ריצה ב-CV עבור FAISS-kNN (עם אימפיוט) =====
def run_faiss_cv(df, y_col, k, n_splits):
    X = df[FEATURE_COLUMNS].values.astype('float32')
    y = df[y_col].values.astype('int64')
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    accs, f1s = [], []
    for tr, te in skf.split(X, y):
        imputer = SimpleImputer(strategy='median')
        X_tr = imputer.fit_transform(X[tr])
        X_te = imputer.transform(X[te])
        acc, f1 = vectordb(X_tr, X_te, y[tr], y[te], k=min(k, len(tr)))
        accs.append(acc); f1s.append(f1)
    return np.array(accs), np.array(f1s)

# ===== מיפוי y מ-ping =====
from rank import rank_qoe_3_classes, rank_str_to_int_mapping_3_classes

# ===== הרצה על כל הקבצים =====
warnings.filterwarnings("ignore", category=UserWarning)
# אם אתה רוצה להסתיר גם FutureWarning ספציפי:
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn.linear_model")

for file in files:
    print(f"\n{BLUE}=== File: {file} ==={RESET}")
    try:
        df_raw = pd.read_csv(file)
    except Exception:
        show_exc("reading CSV")
        continue

    must = FEATURE_COLUMNS + ['ping']
    missing = ensure_columns(df_raw, must)
    if missing:
        print(YELLOW + f"skip: missing columns: {missing}" + RESET)
        continue

    # לא מורידים שורות עם NaN בפיצ'רים (נטפל באימפיוט בתוך CV),
    # כן מסירים שורות שאין להן ping (אי אפשר לתייג)
    df = df_raw.dropna(subset=['ping']).copy()
    if df.empty:
        print(YELLOW + "skip: no rows (ping is NaN everywhere)" + RESET)
        continue

    # יצירת תוויות y לפי ping
    try:
        df['y'] = df['ping'].apply(lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)])
    except Exception:
        show_exc("label from ping")
        continue

    yv = df['y'].values.astype('int64')
    n_splits = safe_n_splits(yv, max_splits=5)
    print(f"rows={len(df)}, class_counts={class_counts(yv)}, n_splits={n_splits}")

    # מודלים
    models = make_models(n_classes=3)

    # הרצת המודלים עם CV
    for name, clf in models:
        try:
            accs, f1s = run_cv(df, clf, y_col='y', n_splits=n_splits)
            print(f"{name:>10} → {GREEN}Accuracy{RESET} {accs.mean():.3f} ± {accs.std():.3f} | "
                  f"{RED}Macro-F1{RESET} {f1s.mean():.3f} ± {f1s.std():.3f}")
        except Exception:
            print(RED + f"MODEL FAILED: {name}" + RESET)
            show_exc("model fit/predict")

    # FAISS-kNN
    try:
        k = 5
        accs, f1s = run_faiss_cv(df, y_col='y', k=k, n_splits=n_splits)
        print(f"{YELLOW}FAISS (k={k}){RESET} → {GREEN}Accuracy{RESET} {accs.mean():.3f} ± {accs.std():.3f} | "
              f"{RED}Macro-F1{RESET} {f1s.mean():.3f} ± {f1s.std():.3f}")
    except Exception:
        print(RED + "FAISS FAILED" + RESET)
        show_exc("FAISS CV")

# %%
df = pd.read_csv("output/window_15_1756035248.csv")

t_df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()
max_k=1

accs ,f1s=vectordb5filde(t_df,max_k)
print(f"AVG over 5 folds →{GREEN} Accuracy:{RESET} {np.mean(accs):.3f}| "
                    f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f}            k={max_k}")

max_k=3

accs ,f1s=vectordb5filde(t_df,max_k)
print(f"AVG over 5 folds →{GREEN} Accuracy:{RESET} {np.mean(accs):.3f}| "
                    f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f}            k={max_k}")

max_k=5

accs ,f1s=vectordb5filde(t_df,max_k)
print(f"AVG over 5 folds →{GREEN} Accuracy:{RESET} {np.mean(accs):.3f}| "
                    f"{RED}Macro-F1:{RESET} {np.mean(f1s):.3f}            k={max_k}")
# Out:
# AVG over 5 folds → Accuracy: 0.946| Macro-F1: 0.947            k=1
# AVG over 5 folds → Accuracy: 0.937| Macro-F1: 0.938            k=3
# AVG over 5 folds → Accuracy: 0.929| Macro-F1: 0.930            k=5

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier

# ==== מאפיינים וקבצים ====
from rank import rank_qoe_3_classes, rank_str_to_int_mapping_3_classes

FEATURE_COLUMNS = [
    'src2dst_avg_pkt_size', 'src2dst_avg_pkt_size_mean', 'src2dst_avg_pkt_size_median',
    'src2dst_avg_pkt_size_std', 'src2dst_avg_pkt_size_min', 'src2dst_avg_pkt_size_max',
    'src2dst_pps', 'src2dst_pps_mean', 'src2dst_pps_median',
    'src2dst_pps_std', 'src2dst_pps_min', 'src2dst_pps_max',
    'dst2src_avg_pkt_size', 'dst2src_avg_pkt_size_mean', 'dst2src_avg_pkt_size_median',
    'dst2src_avg_pkt_size_std', 'dst2src_avg_pkt_size_min', 'dst2src_avg_pkt_size_max',
    'dst2src_pps', 'dst2src_pps_mean', 'dst2src_pps_median',
    'dst2src_pps_std', 'dst2src_pps_min', 'dst2src_pps_max',
    'pkt_dir_ratio', 'pkt_dir_ratio_mean', 'pkt_dir_ratio_median',
    'pkt_dir_ratio_std', 'pkt_dir_ratio_min', 'pkt_dir_ratio_max'
]

# ==== טען דאטה (בחרת את הקובץ הזה; אפשר להחליף לכל קובץ אחר) ====
df = pd.read_csv("output/window_15_1756035248.csv")
df = df.dropna(subset=FEATURE_COLUMNS + ['ping']).copy()

# תיוג לפי ping → שלוש מחלקות
df['y'] = df['ping'].apply(lambda p: rank_str_to_int_mapping_3_classes[rank_qoe_3_classes(p)])

# ==== בניית מודלים ====
def make_models(n_classes: int):
    models = [
        ('RF',  RandomForestClassifier(random_state=42)),
        ('DT',  DecisionTreeClassifier(random_state=42)),
        ('LR',  make_pipeline(StandardScaler(),
                              LogisticRegression(random_state=42,
                                                 max_iter=2000,
                                                 solver='lbfgs',
                                                 multi_class='multinomial'))),
        ('SVM', make_pipeline(StandardScaler(), SVC(random_state=42)))
    ]
    xgb = XGBClassifier(
        objective='multi:softprob' if n_classes > 2 else 'binary:logistic',
        num_class=n_classes if n_classes > 2 else None,
        eval_metric='mlogloss' if n_classes > 2 else 'logloss',
        random_state=42, n_estimators=300, max_depth=6,
        learning_rate=0.1, subsample=0.8, colsample_bytree=0.8,
        tree_method='hist'
    )
    models.append(('XGBoost', xgb))
    return models

# ==== 5-Fold CV לכל מודל ====
def five_fold_eval(df, clf, n_splits=5):
    # X, y
    X = df[FEATURE_COLUMNS].values.astype('float32')
    y = df['y'].values.astype('int64')

    # XGBoost (וחלק מהמודלים) מעדיפים/דורשים לייבלים 0..C-1
    le = LabelEncoder()
    y_enc = le.fit_transform(y)  # יהפוך {1,2,3} ל-{0,1,2}

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accs, f1s = [], []

    for tr, te in skf.split(X, y_enc):
        clf.fit(X[tr], y_enc[tr])
        y_pred = clf.predict(X[te])
        accs.append(accuracy_score(y_enc[te], y_pred))
        f1s.append(f1_score(y_enc[te], y_pred, average='macro'))

    return np.array(accs), np.array(f1s)

# ==== הרצה והדפסה ====
models = make_models(n_classes=3)  # יש לנו 3 מחלקות
for name, clf in models:
    accs, f1s = five_fold_eval(df, clf, n_splits=5)
    print(f"{name:>10} → Accuracy {accs.mean():.3f} ± {accs.std():.3f} | Macro-F1 {f1s.mean():.3f} ± {f1s.std():.3f}")
# Out:
#         RF → Accuracy 0.977 ± 0.002 | Macro-F1 0.977 ± 0.002
#         DT → Accuracy 0.941 ± 0.004 | Macro-F1 0.941 ± 0.004
#         LR → Accuracy 0.803 ± 0.004 | Macro-F1 0.793 ± 0.004
#        SVM → Accuracy 0.891 ± 0.003 | Macro-F1 0.890 ± 0.003
#    XGBoost → Accuracy 0.989 ± 0.002 | Macro-F1 0.990 ± 0.002
